# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import time
from datetime import date
from datetime import datetime
from datetime import timedelta

# %%
#from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler 
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.utils import resample
from scipy import stats as st
from scipy.stats import chi2_contingency
from sklearn.preprocessing import PowerTransformer
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression

# %% [markdown]
# # Project :
# # Mergers and Acquisitions EDA - focus Tech companies

# %% [markdown]
# ## Business Questions:

# %% [markdown]
# ### 1) what is the total number of acquistions year on year. did the acquisition rate increase over years:

# %% [markdown]
# ### 2) Parent company ranking by number of acquisitions and total deal value year on year

# %% [markdown]
# ### 3) What is the pattern of acquistion over the years ( in which businesses is MnA concentrated):

# %% [markdown]
# ### 4) Countries with the highest acquisition rate year on year ranking and total value

# %% [markdown]
# load 2 data setsf for comparison and choice of better data quality:

# %%
data= pd.read_csv('acquisitions.csv')
data.head()
# Out:
#   AcquisitionID AcquisitionMonth  AcquisitionMonthDate  AcquisitionYear  \
# 0         ACQ99         November                  11.0             2015
# 1         ACQ98         November                  11.0             2015
# 2         ACQ97         December                   8.0             2015
# 3         ACQ96         December                  18.0             2015
# 4         ACQ95         December                  21.0             2015
#
#        Company                      Business Country  Value (USD)  \
# 0        bebop                Cloud software     USA  380000000.0
# 1     Fly Labs                 Video editing     USA          NaN
# 2    Clearleap  Cloud-based video management     USA          NaN
# 3   Metanautix            Big Data Analytics     USA          NaN
# 4  Talko, Inc.         Mobile communications     USA          NaN
#
#         Derived products ParentCompany
# 0  Google Cloud Platform        Google
# 1          Google Photos        Google
# 2                    NaN           IBM
# 3                    NaN     Microsoft
# 4                    NaN     Microsoft

# %%
data.isna().sum()
# Out:
# AcquisitionID             0
# AcquisitionMonth          6
# AcquisitionMonthDate     33
# AcquisitionYear           0
# Company                   0
# Business                  0
# Country                  46
# Value (USD)             671
# Derived products        515
# ParentCompany             0
# dtype: int64

# %%
len(data), len(data.dropna())
# Out:
# (916, 114)

# %% [markdown]
# In percentage:

# %%
((data.isna().sum())/len(data))*100
# Out:
# AcquisitionID            0.000000
# AcquisitionMonth         0.655022
# AcquisitionMonthDate     3.602620
# AcquisitionYear          0.000000
# Company                  0.000000
# Business                 0.000000
# Country                  5.021834
# Value (USD)             73.253275
# Derived products        56.222707
# ParentCompany            0.000000
# dtype: float64

# %%
data1= pd.read_excel('acquisitions_update_2021-trial.xlsx')
data1.head()
# Out:
#    ID Parent Company Acquisition Year Acquisition Month  \
# 0   1          Apple             1988               Mar
# 1   2          Apple             1988               Jun
# 2   3          Apple             1988               Jun
# 3   4          Apple             1988               Jul
# 4   5          Apple             1989               Jan
#
#         Acquired Company           Business Country Acquisition Price  \
# 0    Network Innovations           Software       -                 -
# 1  Orion Network Systems  Computer Software       -                 -
# 2              Styleware  Computer software       -                 -
# 3        Nashoba Systems  Computer software       -                 -
# 4         Coral Software  Computer software       -                 -
#
#   Category Derived Products
# 0        -                -
# 1        -                -
# 2        -                -
# 3        -                -
# 4        -                -

# %%
len(data1), len(data1.dropna())
# Out:
# (1455, 1455)

# %% [markdown]
# Although data1 ( the updated data file has more rows, it also has no null values. it has a lot of '-'values in updated file. these values are first changed to null values and then the data quality is checked accordingly.

# %%
data1=data1.replace('-',np.NaN)

# %%
(data1.isna().sum())
# Out:
# ID                      0
# Parent Company          0
# Acquisition Year       28
# Acquisition Month      58
# Acquired Company        0
# Business              274
# Country              1114
# Acquisition Price     945
# Category             1445
# Derived Products     1052
# dtype: int64

# %% [markdown]
# In percentage:

# %%
((data1.isna().sum())/len(data1))*100
# Out:
# ID                    0.000000
# Parent Company        0.000000
# Acquisition Year      1.924399
# Acquisition Month     3.986254
# Acquired Company      0.000000
# Business             18.831615
# Country              76.563574
# Acquisition Price    64.948454
# Category             99.312715
# Derived Products     72.302405
# dtype: float64

# %%
len(data1), len(data1.dropna())
# Out:
# (1455, 0)

# %% [markdown]
# Given the business questions to be answered, comparing both data sets, the first dataset "data" is the preferred choice for the EDA. should there by excess time, data1 can be revisited to extract further inofrmation to further populate  acquistion price

# %%
#data1.loc[1]['Parent Company']

# %%
#data1['Acquired Company']+'-'+data1['Acquired Company']

# %%
data1['parent-acquired'] = data1['Parent Company']+'-'+data1['Acquired Company']

# %%
data1.head()
# Out:
#    ID Parent Company  Acquisition Year Acquisition Month  \
# 0   1          Apple            1988.0               Mar
# 1   2          Apple            1988.0               Jun
# 2   3          Apple            1988.0               Jun
# 3   4          Apple            1988.0               Jul
# 4   5          Apple            1989.0               Jan
#
#         Acquired Company           Business Country Acquisition Price  \
# 0    Network Innovations           Software     NaN               NaN
# 1  Orion Network Systems  Computer Software     NaN               NaN
# 2              Styleware  Computer software     NaN               NaN
# 3        Nashoba Systems  Computer software     NaN               NaN
# 4         Coral Software  Computer software     NaN               NaN
#
#   Category Derived Products              parent-acquired
# 0      NaN              NaN    Apple-Network Innovations
# 1      NaN              NaN  Apple-Orion Network Systems
# 2      NaN              NaN              Apple-Styleware
# 3      NaN              NaN        Apple-Nashoba Systems
# 4      NaN              NaN         Apple-Coral Software

# %%
data['parent-acquired']= data['ParentCompany']+'-'+data['Company']

# %%
data.head()
# Out:
#   AcquisitionID AcquisitionMonth  AcquisitionMonthDate  AcquisitionYear  \
# 0         ACQ99         November                  11.0             2015
# 1         ACQ98         November                  11.0             2015
# 2         ACQ97         December                   8.0             2015
# 3         ACQ96         December                  18.0             2015
# 4         ACQ95         December                  21.0             2015
#
#        Company                      Business Country  Value (USD)  \
# 0        bebop                Cloud software     USA  380000000.0
# 1     Fly Labs                 Video editing     USA          NaN
# 2    Clearleap  Cloud-based video management     USA          NaN
# 3   Metanautix            Big Data Analytics     USA          NaN
# 4  Talko, Inc.         Mobile communications     USA          NaN
#
#         Derived products ParentCompany        parent-acquired
# 0  Google Cloud Platform        Google           Google-bebop
# 1          Google Photos        Google        Google-Fly Labs
# 2                    NaN           IBM          IBM-Clearleap
# 3                    NaN     Microsoft   Microsoft-Metanautix
# 4                    NaN     Microsoft  Microsoft-Talko, Inc.

# %%
data_data1merge = pd.merge(left = data,
                                  right = data1,
                                  how = 'left', 
                                  left_on = "parent-acquired", 
                                  right_on= "parent-acquired")

# %%
data_data1merge.isna().sum()
# Out:
# AcquisitionID             0
# AcquisitionMonth          6
# AcquisitionMonthDate     33
# AcquisitionYear           0
# Company                   0
# Business_x                0
# Country_x                46
# Value (USD)             671
# Derived products        515
# ParentCompany             0
# parent-acquired           0
# ID                      307
# Parent Company          307
# Acquisition Year        307
# Acquisition Month       312
# Acquired Company        307
# Business_y              374
# Country_y               835
# Acquisition Price       726
# Category                907
# Derived Products        705
# dtype: int64

# %%
data_data1merge=data_data1merge.replace('-',np.NaN)

# %%
new_cols = []
def column_names(df):
    for i in df.columns:
        x = i.lower().replace(' ','_')
        new_cols.append(x)
    df.columns = new_cols
    display(df.head())
    
column_names(data_data1merge)
# Out:
#   acquisitionid acquisitionmonth  acquisitionmonthdate  acquisitionyear  \
# 0         ACQ99         November                  11.0             2015
# 1         ACQ98         November                  11.0             2015
# 2         ACQ97         December                   8.0             2015
# 3         ACQ96         December                  18.0             2015
# 4         ACQ95         December                  21.0             2015
#
#        company                    business_x country_x  value_(usd)  \
# 0        bebop                Cloud software       USA  380000000.0
# 1     Fly Labs                 Video editing       USA          NaN
# 2    Clearleap  Cloud-based video management       USA          NaN
# 3   Metanautix            Big Data Analytics       USA          NaN
# 4  Talko, Inc.         Mobile communications       USA          NaN
#
#         derived_products parentcompany  ...     id  parent_company  \
# 0  Google Cloud Platform        Google  ...  611.0          Google
# 1          Google Photos        Google  ...  610.0          Google
# 2                    NaN           IBM  ...    NaN             NaN
# 3                    NaN     Microsoft  ...  863.0       Microsoft
# 4                    NaN     Microsoft  ...  864.0       Microsoft
#
#   acquisition_year  acquisition_month acquired_company             business_y  \
# 0           2015.0                Nov            bebop         Cloud software
# 1           2015.0                Nov         Fly Labs          Video editing
# 2              NaN                NaN              NaN                    NaN
# 3           2015.0                Dec       Metanautix     Big data analytics
# 4           2015.0                Dec      Talko, Inc.  Mobile communications
#
#   country_y acquisition_price category       derived_products
# 0       NaN         380000000      NaN  Google Cloud Platform
# 1       NaN               NaN      NaN          Google Photos
# 2       NaN               NaN      NaN                    NaN
# 3       NaN               NaN      NaN                    NaN
# 4       NaN               NaN      NaN                    NaN
#
# [5 rows x 21 columns]

# %%
data_data1merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 916 entries, 0 to 915
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   acquisitionid         916 non-null    object
#  1   acquisitionmonth      910 non-null    object
#  2   acquisitionmonthdate  883 non-null    float64
#  3   acquisitionyear       916 non-null    int64
#  4   company               916 non-null    object
#  5   business_x            916 non-null    object
#  6   country_x             870 non-null    object
#  7   value_(usd)           245 non-null    float64
#  8   derived_products      401 non-null    object
#  9   parentcompany         916 non-null    object
#  10  parent-acquired       916 non-null    object
#  11  id                    609 non-null    float64
#  12  parent_company        609 non-null    object
#  13  acquisition_year      609 non-null    float64
#  14  acquisition_month     604 non-null    object
#  15  acquired_company      609 non-null    object
#  16  business_y            542 non-null    object
#  17  country_y             81 non-null     object
#  18  acquisition_price     190 non-null    object
#  19  category              9 non-null      object
#  20  derived_products      211 non-null    object
# dtypes: float64(4), int64(1), object(16)
# memory usage: 157.4+ KB

# %%
data_data1merge['acquisition_price']=pd.to_numeric(data_data1merge['acquisition_price'], errors='coerce')

# %%
list(data_data1merge.columns).index('value_(usd)')
# Out:
# 7

# %%
list(data_data1merge.columns).index('acquisition_price')
# Out:
# 18

# %%
na_in_value_indexes=list(data_data1merge[data_data1merge['value_(usd)'].isna()==True].index)

# %%
data_data1merge.iloc[na_in_value_indexes,7]=data_data1merge.iloc[na_in_value_indexes,18]

# %%
list (data_data1merge.columns).index('country_x')
# Out:
# 6

# %%
list(data_data1merge.columns).index('country_y')
# Out:
# 17

# %%
na_in_country_indexes=list(data_data1merge[data_data1merge['country_x'].isna()==True].index)

# %%
data_data1merge.iloc[na_in_country_indexes,6]=data_data1merge.iloc[na_in_country_indexes,17]

# %%
data_data1merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 916 entries, 0 to 915
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   acquisitionid         916 non-null    object
#  1   acquisitionmonth      910 non-null    object
#  2   acquisitionmonthdate  883 non-null    float64
#  3   acquisitionyear       916 non-null    int64
#  4   company               916 non-null    object
#  5   business_x            916 non-null    object
#  6   country_x             875 non-null    object
#  7   value_(usd)           256 non-null    float64
#  8   derived_products      401 non-null    object
#  9   parentcompany         916 non-null    object
#  10  parent-acquired       916 non-null    object
#  11  id                    609 non-null    float64
#  12  parent_company        609 non-null    object
#  13  acquisition_year      609 non-null    float64
#  14  acquisition_month     604 non-null    object
#  15  acquired_company      609 non-null    object
#  16  business_y            542 non-null    object
#  17  country_y             81 non-null     object
#  18  acquisition_price     157 non-null    float64
#  19  category              9 non-null      object
#  20  derived_products      211 non-null    object
# dtypes: float64(5), int64(1), object(15)
# memory usage: 157.4+ KB

# %%
list (data_data1merge.columns)[8]
# Out:
# 'derived_products'

# %% [markdown]
# na_in_derived_products_indexes=list(data_data1merge[data_data1merge[(data_data1merge.columns)[8]].isna()==True].index)
#
# 2 columns with the name derived_products resulting in failure to index NaN value. plan: splice rename and concatenate back.

# %%
data_data1merge.shape
# Out:
# (916, 21)

# %%
data1=data_data1merge.iloc[ : , :-1]

# %%
data1.shape
# Out:
# (916, 20)

# %%
derived_product=data_data1merge.iloc[ : ,20]

# %%
derived_products=pd.DataFrame(derived_product)
derived_products=derived_products.rename(columns={'derived_products':'derived_products_y'})
derived_products
# Out:
#                      derived_products_y
# 0                 Google Cloud Platform
# 1                         Google Photos
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 911                                 NaN
# 912                                 NaN
# 913  Google Play Music, Google Podcasts
# 914                                 NaN
# 915                                 NaN
#
# [916 rows x 1 columns]

# %%
type(derived_products)
# Out:
# pandas.core.frame.DataFrame

# %%
data_data1merge=pd.concat([data1,derived_products], axis=1)
data_data1merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 916 entries, 0 to 915
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   acquisitionid         916 non-null    object
#  1   acquisitionmonth      910 non-null    object
#  2   acquisitionmonthdate  883 non-null    float64
#  3   acquisitionyear       916 non-null    int64
#  4   company               916 non-null    object
#  5   business_x            916 non-null    object
#  6   country_x             875 non-null    object
#  7   value_(usd)           256 non-null    float64
#  8   derived_products      401 non-null    object
#  9   parentcompany         916 non-null    object
#  10  parent-acquired       916 non-null    object
#  11  id                    609 non-null    float64
#  12  parent_company        609 non-null    object
#  13  acquisition_year      609 non-null    float64
#  14  acquisition_month     604 non-null    object
#  15  acquired_company      609 non-null    object
#  16  business_y            542 non-null    object
#  17  country_y             81 non-null     object
#  18  acquisition_price     157 non-null    float64
#  19  category              9 non-null      object
#  20  derived_products_y    211 non-null    object
# dtypes: float64(5), int64(1), object(15)
# memory usage: 157.4+ KB

# %%
na_in_derivedproducts_indexes=list(data_data1merge[data_data1merge['derived_products'].isna()==True].index)

# %%
data_data1merge.iloc[na_in_derivedproducts_indexes,8]=data_data1merge.iloc[na_in_derivedproducts_indexes,20]

# %%
data_data1merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 916 entries, 0 to 915
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   acquisitionid         916 non-null    object
#  1   acquisitionmonth      910 non-null    object
#  2   acquisitionmonthdate  883 non-null    float64
#  3   acquisitionyear       916 non-null    int64
#  4   company               916 non-null    object
#  5   business_x            916 non-null    object
#  6   country_x             875 non-null    object
#  7   value_(usd)           256 non-null    float64
#  8   derived_products      402 non-null    object
#  9   parentcompany         916 non-null    object
#  10  parent-acquired       916 non-null    object
#  11  id                    609 non-null    float64
#  12  parent_company        609 non-null    object
#  13  acquisition_year      609 non-null    float64
#  14  acquisition_month     604 non-null    object
#  15  acquired_company      609 non-null    object
#  16  business_y            542 non-null    object
#  17  country_y             81 non-null     object
#  18  acquisition_price     157 non-null    float64
#  19  category              9 non-null      object
#  20  derived_products_y    211 non-null    object
# dtypes: float64(5), int64(1), object(15)
# memory usage: 157.4+ KB

# %%
na_in_acquistionmonth_indexes=list(data_data1merge[data_data1merge['acquisitionmonth'].isna()==True].index)
data_data1merge.iloc[na_in_acquistionmonth_indexes,1]=data_data1merge.iloc[na_in_acquistionmonth_indexes,14]

# %%
data_data1merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 916 entries, 0 to 915
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   acquisitionid         916 non-null    object
#  1   acquisitionmonth      910 non-null    object
#  2   acquisitionmonthdate  883 non-null    float64
#  3   acquisitionyear       916 non-null    int64
#  4   company               916 non-null    object
#  5   business_x            916 non-null    object
#  6   country_x             875 non-null    object
#  7   value_(usd)           256 non-null    float64
#  8   derived_products      402 non-null    object
#  9   parentcompany         916 non-null    object
#  10  parent-acquired       916 non-null    object
#  11  id                    609 non-null    float64
#  12  parent_company        609 non-null    object
#  13  acquisition_year      609 non-null    float64
#  14  acquisition_month     604 non-null    object
#  15  acquired_company      609 non-null    object
#  16  business_y            542 non-null    object
#  17  country_y             81 non-null     object
#  18  acquisition_price     157 non-null    float64
#  19  category              9 non-null      object
#  20  derived_products_y    211 non-null    object
# dtypes: float64(5), int64(1), object(15)
# memory usage: 157.4+ KB

# %% [markdown]
# All useful data from the merge operation has been extracted. It is time to drop off the extra redundant columns, clean and rename the retained colums:

# %%
dataprecleaning=data_data1merge.iloc[ : , : 11]

# %%
dataprecleaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 916 entries, 0 to 915
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   acquisitionid         916 non-null    object
#  1   acquisitionmonth      910 non-null    object
#  2   acquisitionmonthdate  883 non-null    float64
#  3   acquisitionyear       916 non-null    int64
#  4   company               916 non-null    object
#  5   business_x            916 non-null    object
#  6   country_x             875 non-null    object
#  7   value_(usd)           256 non-null    float64
#  8   derived_products      402 non-null    object
#  9   parentcompany         916 non-null    object
#  10  parent-acquired       916 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 85.9+ KB

# %%
dataprecleaning=dataprecleaning.rename(columns={'acquisitionid':'acquisition_id','acquisitionmonth':'acquisition_month',\
                                                'acquisitionmonthdate':'acquisition_monthdate','acquisitionyear':'acquisition_year',\
                                                'company':'acquired_company','business_x':'business','country_x':'country',\
                                                'value_(usd)':'acquistion_price(mil_usd)','parentcompany':'acquiring_company'})

# %%
dataprecleaning['country']=dataprecleaning['country'].fillna('other')

# %%
dataprecleaning['derived_products']=dataprecleaning['derived_products'].fillna('unclear')

# %%
dataprecleaning['acquisition_monthdate'].mode()[0]
# Out:
# 1.0

# %%
dataprecleaning['acquisition_monthdate'] = dataprecleaning['acquisition_monthdate'].fillna(dataprecleaning['acquisition_monthdate'].mode()[0])

# %%
dataprecleaning['acquisition_month'].mode()
# Out:
# 0    June
# Name: acquisition_month, dtype: object

# %%
dataprecleaning['acquisition_month'] = dataprecleaning['acquisition_month'].fillna(dataprecleaning['acquisition_month'].mode()[0])

# %%
dataprecleaning['acquistion_price(mil_usd)']=(dataprecleaning['acquistion_price(mil_usd)'])/1000000

# %%
dataprecleaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 916 entries, 0 to 915
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   acquisition_id             916 non-null    object
#  1   acquisition_month          916 non-null    object
#  2   acquisition_monthdate      916 non-null    float64
#  3   acquisition_year           916 non-null    int64
#  4   acquired_company           916 non-null    object
#  5   business                   916 non-null    object
#  6   country                    916 non-null    object
#  7   acquistion_price(mil_usd)  256 non-null    float64
#  8   derived_products           916 non-null    object
#  9   acquiring_company          916 non-null    object
#  10  parent-acquired            916 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 85.9+ KB

# %%
dataprecleaning['acquiring_company'].unique()
# Out:
# array(['Google', 'IBM', 'Microsoft', 'Apple', 'Facebook', 'Yahoo',
#        'Twitter'], dtype=object)

# %%
data=dataprecleaning.copy()

# %% [markdown]
# ### 1) What is the total number of acquistions year on year. did the acquisition rate increase over years

# %% [markdown]
# ### Annual Number of acquistions:

# %% [markdown]
# Investigating the avaialbe acquisition data for the last year in the date (2018) :

# %%
data[data['acquisition_year']==2018]
# Out:
#     acquisition_id acquisition_month  acquisition_monthdate  acquisition_year  \
# 359           ACQ6           January                    2.0              2018
# 470           ACQ5           January                   23.0              2018
# 581           ACQ4           January                   29.0              2018
# 692           ACQ3             March                   12.0              2018
# 803           ACQ2             March                   27.0              2018
# 914           ACQ1               May                   18.0              2018
# 915         AcQ916              June                    4.0              2018
#
#       acquired_company                                    business country  \
# 359         Buddybuild     Feedback Platform for Development teams     CAN
# 470            Confirm  Government Issued ID Verification Platform     USA
# 581            Playfab                      Gaming backend service     USA
# 692            Texture       Digital magazine subscription service     USA
# 803              Tenor                            GIF image search     USA
# 914  Semantic Machines                           Conversational AI     USA
# 915             Github                     Version Control Hosting     USA
#
#      acquistion_price(mil_usd)   derived_products acquiring_company  \
# 359                        NaN  Xcode, TestFlight             Apple
# 470                        NaN            unclear          Facebook
# 581                        NaN            unclear         Microsoft
# 692                        NaN               News             Apple
# 803                        NaN      Google Images            Google
# 914                      400.0            unclear         Microsoft
# 915                     7500.0            unclear         Microsoft
#
#                  parent-acquired
# 359             Apple-Buddybuild
# 470             Facebook-Confirm
# 581            Microsoft-Playfab
# 692                Apple-Texture
# 803                 Google-Tenor
# 914  Microsoft-Semantic Machines
# 915             Microsoft-Github

# %% [markdown]
# Data runs only until end of Q2 2018. if displayed, it will provided incorrect insight about the state of affairs in 2018 and potential trends as a result. Hence, 2018 data will not be considered for the analysis.

# %%
data=data[data['acquisition_year']!=2018]

# %%
plt.figure(figsize = (20,5))
plt.title("Annual number of acquistions Year on Year")
sns.countplot(x='acquisition_year',data=data);

# %%
plt.figure(figsize = (20,5))
data['acquisition_year'].value_counts(sort = True,ascending=True).plot.bar(grid = True) 
plt.xlabel("acquisition_year")
plt.ylabel("number of acquistions")
plt.title("Annual number of acquistions sorted in ascending order")
plt.show()

# %%
plt.figure(figsize=(20, 5))
sns.set_style("ticks")
plt.title("Annual number of acquistions Year on Year", fontsize=30, fontweight="bold")
plt.xlabel("Acquisition year", fontsize=25)
plt.ylabel("number of acquisitions", fontsize=25)
sns.histplot(data=data, x="acquisition_year", kde=True, bins=25)
# Out:
# <AxesSubplot:title={'center':'Annual number of acquistions Year on Year'}, xlabel='Acquisition year', ylabel='number of acquisitions'>

# %% [markdown]
# ### 2) Parent company ranking by number of acquisitions and total deal value year on year

# %%
company_acquisitions=data['acquiring_company'].value_counts().reset_index()
company_acquisitions=company_acquisitions.rename(columns={'index':'Acquiring Company', 'acquiring_company':'Acquisitions (1987 to 2017)'})
company_acquisitions
# Out:
#   Acquiring Company  Acquisitions (1987 to 2017)
# 0            Google                          214
# 1         Microsoft                          207
# 2               IBM                          162
# 3             Yahoo                          114
# 4             Apple                           93
# 5          Facebook                           66
# 6           Twitter                           53

# %% [markdown]
# plt.figure(figsize=(20, 10))
# sns.set_style("ticks")
# plt.title("Number of M&A by Acquiring company", fontsize=30, fontweight="bold")
# plt.xlabel("Acquisition Year", fontsize=25)
# plt.ylabel("Companies Acquired", fontsize=25)
# sns.barplot(data=companies, x="Company",
#             y="Acquired Companies", palette="colorblind")
# sns.despine(offset=15, trim=True)

# %%
text = ('Worth noting: while Ibm and Yahoo have returned lower adjusted EBITDA compapred to Apple and Facbook' 
        + '\n' + ' despite making more more acquistions.Not withstanding value of acquisitionss,' + 
        '\n' + 'this may suggest lower M&A efficiency,realized synergies, ROTA and ROCE')
plt.figure(figsize=(25,10))
plt.title('Number of M&A by Acquiring company',fontsize=30, fontweight="bold")
plt.xlabel('Acquiring Company', fontsize=25)
plt.ylabel("Acquisitions (1987 to 2017)", fontsize=25)
sns.barplot(x='Acquiring Company', y='Acquisitions (1987 to 2017)', data=company_acquisitions)
plt.text(x=2, y=170, s=text, size='xx-large')
sns.despine()
plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=15);

# %% [markdown]
# ### 3) Acquiring companyies ranking by total deal value

# %%
data.columns
# Out:
# Index(['acquisition_id', 'acquisition_month', 'acquisition_monthdate',
#        'acquisition_year', 'acquired_company', 'business', 'country',
#        'acquistion_price(mil_usd)', 'derived_products', 'acquiring_company',
#        'parent-acquired'],
#       dtype='object')

# %%
companytotalacquisitionprice=data.groupby("acquiring_company").agg({"acquistion_price(mil_usd)": sum})
companytotalacquisitionprice=companytotalacquisitionprice.reset_index().sort_values("acquistion_price(mil_usd)", ascending=False)
companytotalacquisitionprice
# Out:
#   acquiring_company  acquistion_price(mil_usd)
# 4         Microsoft                  63097.064
# 3               IBM                  36268.000
# 2            Google                  30277.200
# 1          Facebook                  22624.700
# 6             Yahoo                  18097.100
# 0             Apple                   7080.426
# 5           Twitter                   1668.170

# %%
companytotalacquisitionprice=companytotalacquisitionprice.rename(columns={'acquiring_company':'Acquiring Company', 'acquistion_price(mil_usd)':'Acquisitions (1987 to 2017)'})

# %%
text = ('Worth noting: while Ibm and Yahoo have returned lower adjusted EBITDA compapred to Apple and Facbook' 
        + '\n' + ' despite making more more acquistions.Not withstanding value of acquisitionss,' + 
        '\n' + 'this may suggest lower M&A efficiency,realized synergies, ROTA and ROCE')
plt.figure(figsize=(25,10))
plt.title('Total M&A spend by Acquiring company (1988-2017)',fontsize=30, fontweight="bold")
plt.xlabel('Acquiring company', fontsize=25)
plt.ylabel("Total Spend MUSD (1987 to 2017)", fontsize=25)
sns.barplot(x='Acquiring Company', y='Acquisitions (1987 to 2017)', data=company_acquisitions)
plt.text(x=2, y=170, s=text, size='xx-large')
sns.despine()
plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=30);

# %%
company_acq_price_by_year = data.groupby(["acquiring_company",'acquisition_year']).agg({"acquistion_price(mil_usd)": sum})
company_acq_price_by_year.reset_index()
# Out:
#     acquiring_company  acquisition_year  acquistion_price(mil_usd)
# 0               Apple              1988                      0.000
# 1               Apple              1989                      0.000
# 2               Apple              1997                    514.000
# 3               Apple              1999                     19.926
# 4               Apple              2000                      0.000
# ..                ...               ...                        ...
# 114             Yahoo              2011                    330.000
# 115             Yahoo              2012                      0.000
# 116             Yahoo              2013                   1271.500
# 117             Yahoo              2014                    855.000
# 118             Yahoo              2015                    160.000
#
# [119 rows x 3 columns]

# %%
company_acq_price_by_year.to_csv('company_acitivity2.csv')

# %%
companyacqprincebyyear1=company_acq_price_by_year.unstack(level=-1)
companyacqprincebyyear1#.reset_index(drop=True)
# Out:
#                   acquistion_price(mil_usd)                                  \
# acquisition_year                       1987 1988 1989 1991 1992   1994 1995
# acquiring_company
# Apple                                   NaN  0.0  0.0  NaN  NaN    NaN  NaN
# Facebook                                NaN  NaN  NaN  NaN  NaN    NaN  NaN
# Google                                  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# IBM                                     NaN  NaN  NaN  NaN  NaN    NaN  NaN
# Microsoft                              14.0  NaN  NaN  0.0  0.0  130.0  0.0
# Twitter                                 NaN  NaN  NaN  NaN  NaN    NaN  NaN
# Yahoo                                   NaN  NaN  NaN  NaN  NaN    NaN  NaN
#
#                                          ...                           \
# acquisition_year     1996   1997   1998  ...    2008     2009    2010
# acquiring_company                        ...
# Apple                 NaN  514.0    NaN  ...   278.0    17.00   437.0
# Facebook              NaN    NaN    NaN  ...    31.0    47.50    81.0
# Google                NaN    NaN    NaN  ...    15.0   913.00   662.2
# IBM                   NaN    NaN    NaN  ...  6685.0  1200.00  4260.0
# Microsoft          147.15  945.0  305.0  ...  2257.0    35.00     0.0
# Twitter               NaN    NaN    NaN  ...     0.0     5.17     0.0
# Yahoo                 NaN   93.4  107.3  ...   160.0   187.00    55.0
#
#
# acquisition_year      2011    2012    2013     2014    2015     2016    2017
# acquiring_company
# Apple                657.0   406.0   615.0   3030.0    97.5    200.0   630.0
# Facebook              70.0  1100.0   185.0  21050.0    60.0      0.0     0.0
# Google             13931.0   637.0  1184.0   4890.0   380.0    725.0  1100.0
# IBM                  827.0  1470.0  3330.0      0.0  2309.0   2800.0     0.0
# Microsoft           8600.0  1200.0  7200.0   2600.0   620.0  26450.0   150.0
# Twitter               40.0    30.0   530.0    284.0   629.0    150.0     NaN
# Yahoo                330.0     0.0  1271.5    855.0   160.0      NaN     NaN
#
# [7 rows x 29 columns]

# %%
#companyacqprincebyyear1.to_csv('company_acitivity1.csv')
type(companyacqprincebyyear1)
# Out:
# pandas.core.frame.DataFrame

# %%
#companies=['Apple','Facebook','Google','IBM','Microsoft','Twitter','Yahoo']
acquisitionyears=[1987, 1988, 1989, 1991, 1992, 1994, 1995, 1996, 1997, 1998, 1999,
            2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
            2011, 2012, 2013, 2014, 2015, 2016, 2017]

# %%
#companies_dictionary={'Acquiring Company':companies}
years_dictionary={'Acquisition Years':acquisitionyears}

# %%
#acquiring_companies_df=pd.DataFrame(acquiring_companies)
#acquiring_companies_df
acquiring_years_df=pd.DataFrame(years_dictionary)
#acquiring_years_df

# %%
acquiring_activity_yoy=pd.concat([companyacqprincebyyear,acquiring_years_df],axis=1)
acquiring_activity_yoy.reset_index()
# Out:
#     index  (acquistion_price(mil_usd), Apple)  \
# 0    1987                                 NaN
# 1    1988                               0.000
# 2    1989                               0.000
# 3    1991                                 NaN
# 4    1992                                 NaN
# 5    1994                                 NaN
# 6    1995                                 NaN
# 7    1996                                 NaN
# 8    1997                             514.000
# 9    1998                                 NaN
# 10   1999                              19.926
# 11   2000                               0.000
# 12   2001                              81.000
# 13   2002                              98.000
# 14   2003                                 NaN
# 15   2004                                 NaN
# 16   2005                               0.000
# 17   2006                               0.000
# 18   2007                                 NaN
# 19   2008                             278.000
# 20   2009                              17.000
# 21   2010                             437.000
# 22   2011                             657.000
# 23   2012                             406.000
# 24   2013                             615.000
# 25   2014                            3030.000
# 26   2015                              97.500
# 27   2016                             200.000
# 28   2017                             630.000
# 29      0                                 NaN
# 30      1                                 NaN
# 31      2                                 NaN
# 32      3                                 NaN
# 33      4                                 NaN
# 34      5                                 NaN
# 35      6                                 NaN
# 36      7                                 NaN
# 37      8                                 NaN
# 38      9                                 NaN
# 39     10                                 NaN
# 40     11                                 NaN
# 41     12                                 NaN
# 42     13                                 NaN
# 43     14                                 NaN
# 44     15                                 NaN
# 45     16                                 NaN
# 46     17                                 NaN
# 47     18                                 NaN
# 48     19                                 NaN
# 49     20                                 NaN
# 50     21                                 NaN
# 51     22                                 NaN
# 52     23                                 NaN
# 53     24                                 NaN
# 54     25                                 NaN
# 55     26                                 NaN
# 56     27                                 NaN
# 57     28                                 NaN
#
#     (acquistion_price(mil_usd), Facebook)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    0.2
# 17                                    NaN
# 18                                    0.0
# 19                                   31.0
# 20                                   47.5
# 21                                   81.0
# 22                                   70.0
# 23                                 1100.0
# 24                                  185.0
# 25                                21050.0
# 26                                   60.0
# 27                                    0.0
# 28                                    0.0
# 29                                    NaN
# 30                                    NaN
# 31                                    NaN
# 32                                    NaN
# 33                                    NaN
# 34                                    NaN
# 35                                    NaN
# 36                                    NaN
# 37                                    NaN
# 38                                    NaN
# 39                                    NaN
# 40                                    NaN
# 41                                    NaN
# 42                                    NaN
# 43                                    NaN
# 44                                    NaN
# 45                                    NaN
# 46                                    NaN
# 47                                    NaN
# 48                                    NaN
# 49                                    NaN
# 50                                    NaN
# 51                                    NaN
# 52                                    NaN
# 53                                    NaN
# 54                                    NaN
# 55                                    NaN
# 56                                    NaN
# 57                                    NaN
#
#     (acquistion_price(mil_usd), Google)  (acquistion_price(mil_usd), IBM)  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
# 5                                   NaN                               NaN
# 6                                   NaN                               NaN
# 7                                   NaN                               NaN
# 8                                   NaN                               NaN
# 9                                   NaN                               NaN
# 10                                  NaN                               NaN
# 11                                  NaN                               NaN
# 12                                  0.0                            1080.0
# 13                                  NaN                            3629.0
# 14                                102.0                            2100.0
# 15                                  0.0                             170.0
# 16                                 50.0                            1282.0
# 17                               1780.0                            4505.0
# 18                               3908.0                             621.0
# 19                                 15.0                            6685.0
# 20                                913.0                            1200.0
# 21                                662.2                            4260.0
# 22                              13931.0                             827.0
# 23                                637.0                            1470.0
# 24                               1184.0                            3330.0
# 25                               4890.0                               0.0
# 26                                380.0                            2309.0
# 27                                725.0                            2800.0
# 28                               1100.0                               0.0
# 29                                  NaN                               NaN
# 30                                  NaN                               NaN
# 31                                  NaN                               NaN
# 32                                  NaN                               NaN
# 33                                  NaN                               NaN
# 34                                  NaN                               NaN
# 35                                  NaN                               NaN
# 36                                  NaN                               NaN
# 37                                  NaN                               NaN
# 38                                  NaN                               NaN
# 39                                  NaN                               NaN
# 40                                  NaN                               NaN
# 41                                  NaN                               NaN
# 42                                  NaN                               NaN
# 43                                  NaN                               NaN
# 44                                  NaN                               NaN
# 45                                  NaN                               NaN
# 46                                  NaN                               NaN
# 47                                  NaN                               NaN
# 48                                  NaN                               NaN
# 49                                  NaN                               NaN
# 50                                  NaN                               NaN
# 51                                  NaN                               NaN
# 52                                  NaN                               NaN
# 53                                  NaN                               NaN
# 54                                  NaN                               NaN
# 55                                  NaN                               NaN
# 56                                  NaN                               NaN
# 57                                  NaN                               NaN
#
#     (acquistion_price(mil_usd), Microsoft)  \
# 0                                   14.000
# 1                                      NaN
# 2                                      NaN
# 3                                    0.000
# 4                                    0.000
# 5                                  130.000
# 6                                    0.000
# 7                                  147.150
# 8                                  945.000
# 9                                  305.000
# 10                                 184.320
# 11                                2474.550
# 12                                1066.734
# 13                                1878.849
# 14                                 200.450
# 15                                   0.000
# 16                                  25.153
# 17                                  35.858
# 18                                6578.000
# 19                                2257.000
# 20                                  35.000
# 21                                   0.000
# 22                                8600.000
# 23                                1200.000
# 24                                7200.000
# 25                                2600.000
# 26                                 620.000
# 27                               26450.000
# 28                                 150.000
# 29                                     NaN
# 30                                     NaN
# 31                                     NaN
# 32                                     NaN
# 33                                     NaN
# 34                                     NaN
# 35                                     NaN
# 36                                     NaN
# 37                                     NaN
# 38                                     NaN
# 39                                     NaN
# 40                                     NaN
# 41                                     NaN
# 42                                     NaN
# 43                                     NaN
# 44                                     NaN
# 45                                     NaN
# 46                                     NaN
# 47                                     NaN
# 48                                     NaN
# 49                                     NaN
# 50                                     NaN
# 51                                     NaN
# 52                                     NaN
# 53                                     NaN
# 54                                     NaN
# 55                                     NaN
# 56                                     NaN
# 57                                     NaN
#
#     (acquistion_price(mil_usd), Twitter)  (acquistion_price(mil_usd), Yahoo)  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# 5                                    NaN                                 NaN
# 6                                    NaN                                 NaN
# 7                                    NaN                                 NaN
# 8                                    NaN                                93.4
# 9                                    NaN                               107.3
# 10                                   NaN                              9510.0
# 11                                   NaN                               470.9
# 12                                   NaN                                42.0
# 13                                   NaN                               671.0
# 14                                   NaN                              1630.0
# 15                                   NaN                               889.0
# 16                                   NaN                               118.0
# 17                                   NaN                                47.0
# 18                                   NaN                              1500.0
# 19                                  0.00                               160.0
# 20                                  5.17                               187.0
# 21                                  0.00                                55.0
# 22                                 40.00                               330.0
# 23                                 30.00                                 0.0
# 24                                530.00                              1271.5
# 25                                284.00                               855.0
# 26                                629.00                               160.0
# 27                                150.00                                 NaN
# 28                                   NaN                                 NaN
# 29                                   NaN                                 NaN
# 30                                   NaN                                 NaN
# 31                                   NaN                                 NaN
# 32                                   NaN                                 NaN
# 33                                   NaN                                 NaN
# 34                                   NaN                                 NaN
# 35                                   NaN                                 NaN
# 36                                   NaN                                 NaN
# 37                                   NaN                                 NaN
# 38                                   NaN                                 NaN
# 39                                   NaN                                 NaN
# 40                                   NaN                                 NaN
# 41                                   NaN                                 NaN
# 42                                   NaN                                 NaN
# 43                                   NaN                                 NaN
# 44                                   NaN                                 NaN
# 45                                   NaN                                 NaN
# 46                                   NaN                                 NaN
# 47                                   NaN                                 NaN
# 48                                   NaN                                 NaN
# 49                                   NaN                                 NaN
# 50                                   NaN                                 NaN
# 51                                   NaN                                 NaN
# 52                                   NaN                                 NaN
# 53                                   NaN                                 NaN
# 54                                   NaN                                 NaN
# 55                                   NaN                                 NaN
# 56                                   NaN                                 NaN
# 57                                   NaN                                 NaN
#
#     Acquisition Years
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29             1987.0
# 30             1988.0
# 31             1989.0
# 32             1991.0
# 33             1992.0
# 34             1994.0
# 35             1995.0
# 36             1996.0
# 37             1997.0
# 38             1998.0
# 39             1999.0
# 40             2000.0
# 41             2001.0
# 42             2002.0
# 43             2003.0
# 44             2004.0
# 45             2005.0
# 46             2006.0
# 47             2007.0
# 48             2008.0
# 49             2009.0
# 50             2010.0
# 51             2011.0
# 52             2012.0
# 53             2013.0
# 54             2014.0
# 55             2015.0
# 56             2016.0
# 57             2017.0

# %%
acquiring_activity_yoy=acquiring_activity_yoy.rename(columns={'index':'years'})

# %%
acquiring_activity_yoy
# Out:
#       (acquistion_price(mil_usd), Apple)  \
# 1987                                 NaN
# 1988                               0.000
# 1989                               0.000
# 1991                                 NaN
# 1992                                 NaN
# 1994                                 NaN
# 1995                                 NaN
# 1996                                 NaN
# 1997                             514.000
# 1998                                 NaN
# 1999                              19.926
# 2000                               0.000
# 2001                              81.000
# 2002                              98.000
# 2003                                 NaN
# 2004                                 NaN
# 2005                               0.000
# 2006                               0.000
# 2007                                 NaN
# 2008                             278.000
# 2009                              17.000
# 2010                             437.000
# 2011                             657.000
# 2012                             406.000
# 2013                             615.000
# 2014                            3030.000
# 2015                              97.500
# 2016                             200.000
# 2017                             630.000
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
# 20                                   NaN
# 21                                   NaN
# 22                                   NaN
# 23                                   NaN
# 24                                   NaN
# 25                                   NaN
# 26                                   NaN
# 27                                   NaN
# 28                                   NaN
#
#       (acquistion_price(mil_usd), Facebook)  \
# 1987                                    NaN
# 1988                                    NaN
# 1989                                    NaN
# 1991                                    NaN
# 1992                                    NaN
# 1994                                    NaN
# 1995                                    NaN
# 1996                                    NaN
# 1997                                    NaN
# 1998                                    NaN
# 1999                                    NaN
# 2000                                    NaN
# 2001                                    NaN
# 2002                                    NaN
# 2003                                    NaN
# 2004                                    NaN
# 2005                                    0.2
# 2006                                    NaN
# 2007                                    0.0
# 2008                                   31.0
# 2009                                   47.5
# 2010                                   81.0
# 2011                                   70.0
# 2012                                 1100.0
# 2013                                  185.0
# 2014                                21050.0
# 2015                                   60.0
# 2016                                    0.0
# 2017                                    0.0
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
#
#       (acquistion_price(mil_usd), Google)  (acquistion_price(mil_usd), IBM)  \
# 1987                                  NaN                               NaN
# 1988                                  NaN                               NaN
# 1989                                  NaN                               NaN
# 1991                                  NaN                               NaN
# 1992                                  NaN                               NaN
# 1994                                  NaN                               NaN
# 1995                                  NaN                               NaN
# 1996                                  NaN                               NaN
# 1997                                  NaN                               NaN
# 1998                                  NaN                               NaN
# 1999                                  NaN                               NaN
# 2000                                  NaN                               NaN
# 2001                                  0.0                            1080.0
# 2002                                  NaN                            3629.0
# 2003                                102.0                            2100.0
# 2004                                  0.0                             170.0
# 2005                                 50.0                            1282.0
# 2006                               1780.0                            4505.0
# 2007                               3908.0                             621.0
# 2008                                 15.0                            6685.0
# 2009                                913.0                            1200.0
# 2010                                662.2                            4260.0
# 2011                              13931.0                             827.0
# 2012                                637.0                            1470.0
# 2013                               1184.0                            3330.0
# 2014                               4890.0                               0.0
# 2015                                380.0                            2309.0
# 2016                                725.0                            2800.0
# 2017                               1100.0                               0.0
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
# 5                                     NaN                               NaN
# 6                                     NaN                               NaN
# 7                                     NaN                               NaN
# 8                                     NaN                               NaN
# 9                                     NaN                               NaN
# 10                                    NaN                               NaN
# 11                                    NaN                               NaN
# 12                                    NaN                               NaN
# 13                                    NaN                               NaN
# 14                                    NaN                               NaN
# 15                                    NaN                               NaN
# 16                                    NaN                               NaN
# 17                                    NaN                               NaN
# 18                                    NaN                               NaN
# 19                                    NaN                               NaN
# 20                                    NaN                               NaN
# 21                                    NaN                               NaN
# 22                                    NaN                               NaN
# 23                                    NaN                               NaN
# 24                                    NaN                               NaN
# 25                                    NaN                               NaN
# 26                                    NaN                               NaN
# 27                                    NaN                               NaN
# 28                                    NaN                               NaN
#
#       (acquistion_price(mil_usd), Microsoft)  \
# 1987                                  14.000
# 1988                                     NaN
# 1989                                     NaN
# 1991                                   0.000
# 1992                                   0.000
# 1994                                 130.000
# 1995                                   0.000
# 1996                                 147.150
# 1997                                 945.000
# 1998                                 305.000
# 1999                                 184.320
# 2000                                2474.550
# 2001                                1066.734
# 2002                                1878.849
# 2003                                 200.450
# 2004                                   0.000
# 2005                                  25.153
# 2006                                  35.858
# 2007                                6578.000
# 2008                                2257.000
# 2009                                  35.000
# 2010                                   0.000
# 2011                                8600.000
# 2012                                1200.000
# 2013                                7200.000
# 2014                                2600.000
# 2015                                 620.000
# 2016                               26450.000
# 2017                                 150.000
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
#
#       (acquistion_price(mil_usd), Twitter)  \
# 1987                                   NaN
# 1988                                   NaN
# 1989                                   NaN
# 1991                                   NaN
# 1992                                   NaN
# 1994                                   NaN
# 1995                                   NaN
# 1996                                   NaN
# 1997                                   NaN
# 1998                                   NaN
# 1999                                   NaN
# 2000                                   NaN
# 2001                                   NaN
# 2002                                   NaN
# 2003                                   NaN
# 2004                                   NaN
# 2005                                   NaN
# 2006                                   NaN
# 2007                                   NaN
# 2008                                  0.00
# 2009                                  5.17
# 2010                                  0.00
# 2011                                 40.00
# 2012                                 30.00
# 2013                                530.00
# 2014                                284.00
# 2015                                629.00
# 2016                                150.00
# 2017                                   NaN
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
#
#       (acquistion_price(mil_usd), Yahoo)  Acquisition Years
# 1987                                 NaN                NaN
# 1988                                 NaN                NaN
# 1989                                 NaN                NaN
# 1991                                 NaN                NaN
# 1992                                 NaN                NaN
# 1994                                 NaN                NaN
# 1995                                 NaN                NaN
# 1996                                 NaN                NaN
# 1997                                93.4                NaN
# 1998                               107.3                NaN
# 1999                              9510.0                NaN
# 2000                               470.9                NaN
# 2001                                42.0                NaN
# 2002                               671.0                NaN
# 2003                              1630.0                NaN
# 2004                               889.0                NaN
# 2005                               118.0                NaN
# 2006                                47.0                NaN
# 2007                              1500.0                NaN
# 2008                               160.0                NaN
# 2009                               187.0                NaN
# 2010                                55.0                NaN
# 2011                               330.0                NaN
# 2012                                 0.0                NaN
# 2013                              1271.5                NaN
# 2014                               855.0                NaN
# 2015                               160.0                NaN
# 2016                                 NaN                NaN
# 2017                                 NaN                NaN
# 0                                    NaN             1987.0
# 1                                    NaN             1988.0
# 2                                    NaN             1989.0
# 3                                    NaN             1991.0
# 4                                    NaN             1992.0
# 5                                    NaN             1994.0
# 6                                    NaN             1995.0
# 7                                    NaN             1996.0
# 8                                    NaN             1997.0
# 9                                    NaN             1998.0
# 10                                   NaN             1999.0
# 11                                   NaN             2000.0
# 12                                   NaN             2001.0
# 13                                   NaN             2002.0
# 14                                   NaN             2003.0
# 15                                   NaN             2004.0
# 16                                   NaN             2005.0
# 17                                   NaN             2006.0
# 18                                   NaN             2007.0
# 19                                   NaN             2008.0
# 20                                   NaN             2009.0
# 21                                   NaN             2010.0
# 22                                   NaN             2011.0
# 23                                   NaN             2012.0
# 24                                   NaN             2013.0
# 25                                   NaN             2014.0
# 26                                   NaN             2015.0
# 27                                   NaN             2016.0
# 28                                   NaN             2017.0

# %%
data5=acquiring_activity_yoy.iloc[ :29, : ]

# %%
data5.head(29)
# Out:
#       (acquistion_price(mil_usd), Apple)  \
# 1987                                 NaN
# 1988                               0.000
# 1989                               0.000
# 1991                                 NaN
# 1992                                 NaN
# 1994                                 NaN
# 1995                                 NaN
# 1996                                 NaN
# 1997                             514.000
# 1998                                 NaN
# 1999                              19.926
# 2000                               0.000
# 2001                              81.000
# 2002                              98.000
# 2003                                 NaN
# 2004                                 NaN
# 2005                               0.000
# 2006                               0.000
# 2007                                 NaN
# 2008                             278.000
# 2009                              17.000
# 2010                             437.000
# 2011                             657.000
# 2012                             406.000
# 2013                             615.000
# 2014                            3030.000
# 2015                              97.500
# 2016                             200.000
# 2017                             630.000
#
#       (acquistion_price(mil_usd), Facebook)  \
# 1987                                    NaN
# 1988                                    NaN
# 1989                                    NaN
# 1991                                    NaN
# 1992                                    NaN
# 1994                                    NaN
# 1995                                    NaN
# 1996                                    NaN
# 1997                                    NaN
# 1998                                    NaN
# 1999                                    NaN
# 2000                                    NaN
# 2001                                    NaN
# 2002                                    NaN
# 2003                                    NaN
# 2004                                    NaN
# 2005                                    0.2
# 2006                                    NaN
# 2007                                    0.0
# 2008                                   31.0
# 2009                                   47.5
# 2010                                   81.0
# 2011                                   70.0
# 2012                                 1100.0
# 2013                                  185.0
# 2014                                21050.0
# 2015                                   60.0
# 2016                                    0.0
# 2017                                    0.0
#
#       (acquistion_price(mil_usd), Google)  (acquistion_price(mil_usd), IBM)  \
# 1987                                  NaN                               NaN
# 1988                                  NaN                               NaN
# 1989                                  NaN                               NaN
# 1991                                  NaN                               NaN
# 1992                                  NaN                               NaN
# 1994                                  NaN                               NaN
# 1995                                  NaN                               NaN
# 1996                                  NaN                               NaN
# 1997                                  NaN                               NaN
# 1998                                  NaN                               NaN
# 1999                                  NaN                               NaN
# 2000                                  NaN                               NaN
# 2001                                  0.0                            1080.0
# 2002                                  NaN                            3629.0
# 2003                                102.0                            2100.0
# 2004                                  0.0                             170.0
# 2005                                 50.0                            1282.0
# 2006                               1780.0                            4505.0
# 2007                               3908.0                             621.0
# 2008                                 15.0                            6685.0
# 2009                                913.0                            1200.0
# 2010                                662.2                            4260.0
# 2011                              13931.0                             827.0
# 2012                                637.0                            1470.0
# 2013                               1184.0                            3330.0
# 2014                               4890.0                               0.0
# 2015                                380.0                            2309.0
# 2016                                725.0                            2800.0
# 2017                               1100.0                               0.0
#
#       (acquistion_price(mil_usd), Microsoft)  \
# 1987                                  14.000
# 1988                                     NaN
# 1989                                     NaN
# 1991                                   0.000
# 1992                                   0.000
# 1994                                 130.000
# 1995                                   0.000
# 1996                                 147.150
# 1997                                 945.000
# 1998                                 305.000
# 1999                                 184.320
# 2000                                2474.550
# 2001                                1066.734
# 2002                                1878.849
# 2003                                 200.450
# 2004                                   0.000
# 2005                                  25.153
# 2006                                  35.858
# 2007                                6578.000
# 2008                                2257.000
# 2009                                  35.000
# 2010                                   0.000
# 2011                                8600.000
# 2012                                1200.000
# 2013                                7200.000
# 2014                                2600.000
# 2015                                 620.000
# 2016                               26450.000
# 2017                                 150.000
#
#       (acquistion_price(mil_usd), Twitter)  \
# 1987                                   NaN
# 1988                                   NaN
# 1989                                   NaN
# 1991                                   NaN
# 1992                                   NaN
# 1994                                   NaN
# 1995                                   NaN
# 1996                                   NaN
# 1997                                   NaN
# 1998                                   NaN
# 1999                                   NaN
# 2000                                   NaN
# 2001                                   NaN
# 2002                                   NaN
# 2003                                   NaN
# 2004                                   NaN
# 2005                                   NaN
# 2006                                   NaN
# 2007                                   NaN
# 2008                                  0.00
# 2009                                  5.17
# 2010                                  0.00
# 2011                                 40.00
# 2012                                 30.00
# 2013                                530.00
# 2014                                284.00
# 2015                                629.00
# 2016                                150.00
# 2017                                   NaN
#
#       (acquistion_price(mil_usd), Yahoo)  Acquisition Years
# 1987                                 NaN                NaN
# 1988                                 NaN                NaN
# 1989                                 NaN                NaN
# 1991                                 NaN                NaN
# 1992                                 NaN                NaN
# 1994                                 NaN                NaN
# 1995                                 NaN                NaN
# 1996                                 NaN                NaN
# 1997                                93.4                NaN
# 1998                               107.3                NaN
# 1999                              9510.0                NaN
# 2000                               470.9                NaN
# 2001                                42.0                NaN
# 2002                               671.0                NaN
# 2003                              1630.0                NaN
# 2004                               889.0                NaN
# 2005                               118.0                NaN
# 2006                                47.0                NaN
# 2007                              1500.0                NaN
# 2008                               160.0                NaN
# 2009                               187.0                NaN
# 2010                                55.0                NaN
# 2011                               330.0                NaN
# 2012                                 0.0                NaN
# 2013                              1271.5                NaN
# 2014                               855.0                NaN
# 2015                               160.0                NaN
# 2016                                 NaN                NaN
# 2017                                 NaN                NaN

# %%
acquiring_activity_yoy.columns
# Out:
# Index([    ('acquistion_price(mil_usd)', 'Apple'),
#         ('acquistion_price(mil_usd)', 'Facebook'),
#           ('acquistion_price(mil_usd)', 'Google'),
#              ('acquistion_price(mil_usd)', 'IBM'),
#        ('acquistion_price(mil_usd)', 'Microsoft'),
#          ('acquistion_price(mil_usd)', 'Twitter'),
#            ('acquistion_price(mil_usd)', 'Yahoo'),
#                               'Acquisition Years'],
#       dtype='object')

# %%
acquiring_activity_yoy=acquiring_activity_yoy.replace(np.NaN,0)
acquiring_activity_yoy

# %%
acquiring_activity_yoy.columns

# %%
plt.figure(figsize=(25,10))
plt.title('lets see',fontsize=30, fontweight="bold")
plt.xlabel('Acquisition Years', fontsize=25)
plt.ylabel("Apple Acquisition Spend MUSD YoY(1987 to 2017)", fontsize=25)
sns.barplot(x='Acquisition Years', y='Apple', data=acquiring_activity_yoy)
sns.despine()
plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=30);

# %%
#fig, ax1 = plt.subplots(1,1,figsize=(15,5)) 
#sns.histplot(binwidth=0.5, x="Acquisition Years", hue=('Apple', 'Facebook', 'Google', 'IBM', 'Microsoft','Twitter', 'Yahoo'), data=acquiring_activity_yoy)

# %%
#company_acq_price_by_year=company_acq_price_by_year.unstack()
#company_acq_price_by_year

# %%
data.country.unique()

# %%
data.country.value_counts()

# %%
company_acquisitions['Acquiring Company'].unique()

# %%
data['country']= data['country'].apply(lambda x: 'USA' if x == 'United States'  else (x))

# %%
data.country.value_counts()

# %%
#data.to_csv('tableau_trial.csv')
